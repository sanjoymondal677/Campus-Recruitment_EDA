# %% [markdown]
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTLcsPooQjDEn_Zmg34dV-Cjpkt4DXc3pGlo10X8NvUXfJ9gMCy2CL_Sg7OFFtUx5i4IJE&usqp=CAU">

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           text-align:center;
#           font-weight:bold;
#           font-size:23px;
#               color:white;">
#     Campus Recruitment
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#     <p style="font-weight:bold;
#               color:#E26A2C;
#               text-align:center">About DataSet:</p>
# <p style="padding: 10px;
#           font-weight:bold;
#           font-size:23px;
#               color:white;">
#    This data set consists of Placement data of students in a XYZ campus. It includes secondary and higher secondary school percentage and specialization. It also includes degree specialization, type and Work experience and salary offers to the placed students
# </p>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#load the dataset
df = pd.read_csv('/home/sanjoy/Desktop/DataSet-kaggle/Placement_Data_Full_Class.csv')
df.head().style.set_properties(**{"background-color": "#ff4654","color": "black","border-color": "black"})
# Out:
# <style type="text/css">
# ...

# %%
df.shape
# Out:
# (215, 15)

# %% [markdown]
# <div style="background-color:#89B5AF;">
#     <p style="font-weight:bold;
#               font-size:18px;
#               color:white">
#         Rows ->215 and Columns ->15
#     </p>
# </div>

# %% [markdown]
# <div style="background-color:#1597E5;">
#     <p style="font-weight:bold;
#               font-size:18px;
#               text-align:center;">
#         Data Cleaning
#     </p>
# </div>

# %%
df.info() #info about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
df.isna().sum() #check for null values
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
sns.heatmap(df.isna(),cbar=False)
plt.show()

# %% [markdown]
# <div style="background-color:#89B5AF;">
#     <p style="font-weight:bold;
#               font-size:18px">
#         Here we can see there is only one column "salary" has the null value
# and we can't drop the Nan value, because those are not get placed their salary is nan so we can replace all nan value with 0 .
#     </p>
# </div>

# %%
df['salary'] = df['salary'].fillna(0) #fill Nan value with zero

# %%
df.isna().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
sns.heatmap(df.isnull(),cbar=False) #check there is still nul value in that column
plt.show()

# %%
df.duplicated().sum() #check for there is duplicated values in the dataset
# Out:
# 0

# %%
df.drop_duplicates(keep="first")
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# <div style="background-color:#89B5AF;">
#     <p style="font-weight:bold;
#               font-size:18px">
#         As we can see there is no duplicated value its show zero  but sometimes have duplicated value and still show zero so for sure use drop fun, keep "first"  to drop all duplicated rows .
#     </p>
# </div>

# %%
df.dtypes #check dtata types
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %% [markdown]
# <div style="background-color:#89B5AF;">
#     <p style="font-weight:bold;
#               font-size:18px">
#         Here we can observed "sl_no" col is not required so we can droped it, If you want keep you can there is no issue
#     </p>
# </div>

# %%
df.drop(['sl_no'],axis=1,inplace = True)

# %%
df.head()
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p      status    salary
# 0     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     No     66.0         Mkt&HR  59.43  Not Placed       0.0
# 4     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df['specialisation'].value_counts()
# Out:
# Mkt&Fin    120
# Mkt&HR      95
# Name: specialisation, dtype: int64

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           text-align:center;
#           font-weight:bold;
#           font-size:23px;
#               color:white;">
#     Which factor influenced a candidate in getting placed?
# </p>
# </div>

# %%
sns.set_style(style='darkgrid', rc={"grid.color": ".8", "grid.linestyle": "--"})
sns.pairplot(df,kind='reg')
plt.show()

# %%
plt.figure(figsize=(14,12))
sns.heatmap(df.corr(), linewidth=0.2,  annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# <div style="background-color:#89B5AF;">
#     <p style="font-weight:bold;
#               font-size:18px;
#               color:white">
#         MBA percenrage and etest precentage are the least significant variable that affect the placement Outcomes.
#     </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           text-align:center;
#           font-weight:bold;
#           font-size:23px;
#               color:white;">
#     Does percentage matters for one to get placed?
# </p>
# </div>

# %%
df['status'].values[df['status']=='Not Placed'] = 0 
df['status'].values[df['status']=='Placed'] = 1
df.status = df.status.astype('int')

# %% [markdown]
# <div style="background-color:#89B5AF;">
#     <p style="font-weight:bold;
#               font-size:18px;
#               color:white">
#         Assign 0 and 1 in place of Not Placed and Placed and converted into interger datatype .
#     </p>
# </div>

# %%
df.head()
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p  status    salary
# 0     No     55.0         Mkt&HR  58.80       1  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28       1  200000.0
# 2     No     75.0        Mkt&Fin  57.80       1  250000.0
# 3     No     66.0         Mkt&HR  59.43       0       0.0
# 4     No     96.8        Mkt&Fin  55.50       1  425000.0

# %%
fig,ax = plt.subplots(3,2, figsize=(10,12))
sns.set_style('darkgrid')
sns.barplot(x=df['status'],y = df['ssc_p'],ax=ax[0,0],color='slateblue')
sns.barplot(x=df['status'],y=df['hsc_p'],ax=ax[0,1],color='orchid')
sns.barplot(x=df['status'],y=df['degree_p'],ax=ax[1,0],color='dodgerblue')
sns.barplot(x=df['status'],y=df['etest_p'],ax=ax[1,1],color='coral')
sns.barplot(x=df['status'],y=df['mba_p'],ax = ax[2,0],color = 'mediumturquoise')

plt.show()

# %%
sns.set_style('darkgrid')
sns.catplot(x="status", y="ssc_p", data=df,)
sns.catplot(x="status", y="hsc_p", data=df)
sns.catplot(x="status", y="degree_p", data=df)
sns.catplot(x="status", y="etest_p", data=df)
sns.catplot(x="status", y="mba_p", data=df)


plt.show()

# %% [markdown]
# <div style="background-color:#89B5AF;">
#     <p style="font-weight:bold;
#               font-size:18px;
#               color:white">
#         By above graph we can say good percentage is required minimum  58 to 60% for geting placement.
# But here we observed MBA percentage deos not effect on  placements .
# And have less percentages , it  doesn't  menas you'll not placed as well high percentages doesn't mena you'll placed
# we observed by those graphs
#     </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           text-align:center;
#           font-weight:bold;
#           font-size:23px;
#               color:white;">
#    Which degree specialization is much demanded by corporate?
# </p>
# </div>

# %%
df.head()
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p  status    salary
# 0     No     55.0         Mkt&HR  58.80       1  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28       1  200000.0
# 2     No     75.0        Mkt&Fin  57.80       1  250000.0
# 3     No     66.0         Mkt&HR  59.43       0       0.0
# 4     No     96.8        Mkt&Fin  55.50       1  425000.0

# %%
df['specialisation'].value_counts()
# Out:
# Mkt&Fin    120
# Mkt&HR      95
# Name: specialisation, dtype: int64

# %%
sns.set_style('darkgrid')
sns.countplot(x=df['specialisation'])
plt.show()

# %%
sns.set_style('darkgrid')
sns.countplot(x='specialisation',data=df,hue = 'status')
plt.show()

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           text-align:center;
#           font-weight:bold;
#           font-size:23px;
#               color:white;">
#    Play with the data conducting all statistical tests.
# </p>
# </div>

# %%
sns.countplot(x = df['gender'])
plt.show()

# %%
grp_gen=pd.DataFrame(df.groupby('gender')['gender'].count())
grp_gen
# Out:
#         gender
# gender
# F           76
# M          139

# %%
colors = ['#99ff99','#ffcc99']
fig1, ax1 = plt.subplots()
explode = (0.03,0.05)
ax1.pie(grp_gen['gender'], labels=['Female','Male'], colors=colors, autopct='%1.1f%%',shadow=True,explode = explode)
ax1.axis('equal')
plt.tight_layout()
plt.show()

# %%
pd.DataFrame(df.groupby(['gender','status'])['status'].count())
# Out:
#                status
# gender status
# F      0           28
#        1           48
# M      0           39
#        1          100

# %%
sns.countplot(x='status',data=df,hue = 'gender')
plt.show()

# %% [markdown]
# <div style="background-color:#89B5AF;">
#     <p style="font-weight:bold;
#               font-size:18px;
#               color:white">
#        100 Males and 28 Females are placed
#     </p>
# </div>

# %%
df['degree_t'].value_counts()
# Out:
# Comm&Mgmt    145
# Sci&Tech      59
# Others        11
# Name: degree_t, dtype: int64

# %%
sns.countplot(x='degree_t',data=df)
plt.show()

# %%
degree_t_grp = pd.DataFrame(df.groupby('degree_t')['degree_t'].count())

# %%
degree_t_grp
# Out:
#            degree_t
# degree_t
# Comm&Mgmt       145
# Others           11
# Sci&Tech         59

# %%
colors = ['#ffcc99','#88E0EF','#161E54']
fig1, ax1 = plt.subplots()
explode = (0.03,0.05,0.05)
ax1.pie(degree_t_grp['degree_t'],labels = ['Comm&Mgmt','Others','Sci&Tech'], colors=colors, autopct='%1.1f%%',shadow=True,explode = explode)
ax1.axis('equal')
plt.tight_layout()
plt.show()

# %%
deg = pd.DataFrame(df.groupby(['degree_t','status'])['status'].count())

# %%
deg
# Out:
#                   status
# degree_t  status
# Comm&Mgmt 0           43
#           1          102
# Others    0            6
#           1            5
# Sci&Tech  0           18
#           1           41

# %%
sns.countplot(x='degree_t',data = df,hue = 'status')
plt.show()

# %% [markdown]
# <div style="background-color:#89B5AF;">
#     <p style="font-weight:bold;
#               font-size:18px;
#               color:white">
#        In degree "Comm&Mgmt" has placed more compare to other degrees
#     </p>
# </div>

# %%
df.head()
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p  status    salary
# 0     No     55.0         Mkt&HR  58.80       1  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28       1  200000.0
# 2     No     75.0        Mkt&Fin  57.80       1  250000.0
# 3     No     66.0         Mkt&HR  59.43       0       0.0
# 4     No     96.8        Mkt&Fin  55.50       1  425000.0

# %%
df['workex'].value_counts()
# Out:
# No     141
# Yes     74
# Name: workex, dtype: int64

# %%
sns.countplot(x='workex',data = df,hue='status')
plt.show()

# %%
work = pd.DataFrame(df.groupby('workex')['workex'].count())

# %%
work
# Out:
#         workex
# workex
# No         141
# Yes         74

# %%
plt.pie(x=work['workex'],labels = ['No','Yes'],autopct='%.0f%%')
plt.show()

# %% [markdown]
# <div style="background-color:#89B5AF;">
#     <p style="font-weight:bold;
#               font-size:18px;
#               color:white">
#         There is more number of freshers get placed.
#     </p>
# </div>

# %%
df['hsc_s'].value_counts()
# Out:
# Commerce    113
# Science      91
# Arts         11
# Name: hsc_s, dtype: int64

# %%
sns.countplot(x='hsc_s',data = df,hue = 'status')
plt.show()

# %%
df.head(3)
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p  status    salary
# 0     No     55.0         Mkt&HR  58.80       1  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28       1  200000.0
# 2     No     75.0        Mkt&Fin  57.80       1  250000.0

# %%
df['ssc_b'].value_counts()
# Out:
# Central    116
# Others      99
# Name: ssc_b, dtype: int64

# %%
ssc_board = pd.DataFrame(df.groupby(['ssc_b','status'])['status'].count())

# %%
ssc_board
# Out:
#                 status
# ssc_b   status
# Central 0           38
#         1           78
# Others  0           29
#         1           70

# %%
sns.countplot(x='ssc_b',data = df,hue = 'status')
plt.show()

# %%
df['hsc_b'].value_counts()
# Out:
# Others     131
# Central     84
# Name: hsc_b, dtype: int64

# %%
hsc_board = pd.DataFrame(df.groupby(['hsc_b','status'])['status'].count())

# %%
hsc_board
# Out:
#                 status
# hsc_b   status
# Central 0           27
#         1           57
# Others  0           40
#         1           91

# %%
sns.countplot(x='hsc_b',data=df,hue='status')
plt.show()

# %% [markdown]
# <div style="background-color:#89B5AF;">
#     <p style="font-weight:bold;
#               font-size:18px;
#               color:white">
#         In hsc_Others board has more get placed then centeral hsc board.
#     </p>
# </div>

# %%
df.head()
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p  status    salary
# 0     No     55.0         Mkt&HR  58.80       1  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28       1  200000.0
# 2     No     75.0        Mkt&Fin  57.80       1  250000.0
# 3     No     66.0         Mkt&HR  59.43       0       0.0
# 4     No     96.8        Mkt&Fin  55.50       1  425000.0

# %%
max_salary = df['salary'].max()
print("The max salary is : ",max_salary)
# Out:
# The max salary is :  940000.0

# %%
sns.barplot(x='specialisation',y= 'salary',data = df,capsize=.1)
plt.show()

# %%
sns.barplot(x='gender',y='salary',data = df,capsize=.2)
plt.title("Gender & Salary",fontweight = 'bold')
plt.xlabel("Gender",fontweight = 'bold')
plt.ylabel("Salary",fontweight = 'bold')
plt.show()

# %% [markdown]
# <p style="text-align:center;
#           font-weight:bold">
# --------------END-------------<br>
# -------------Thank You--------
# </p>

# %% [markdown]
# <img src="https://media1.giphy.com/media/r7Rwd7KDGhzoiJt6vZ/200w.webp?cid=ecf05e47qs2afj0tj9z6cdjb424wfyb3umo33uhy5jrrdfss&rid=200w.webp&ct=g">
